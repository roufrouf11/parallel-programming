# %%
import matplotlib.pyplot as plt

# %%
core1 = []
with open("1.txt", "r") as file:
    lines = file.readlines()
for i, line in enumerate(lines):
    lines[i] = line.split(", ")[1].strip()
core1 = list(map(float, lines))
print(core1)
# Out:
# [0.004172, 0.036008, 0.146063, 0.40128, 0.904292, 1.783768, 3.173883, 5.252589, 8.22626, 12.287038]

# %%
core6 = []
with open("6.txt", "r") as file:
    lines = file.readlines()
for i, line in enumerate(lines):
    lines[i] = line.split(", ")[1].strip()
core6 = list(map(float, lines))
print(core6)
# Out:
# [0.001369, 0.008408, 0.02794, 0.07256, 0.158032, 0.308105, 0.544721, 0.900688, 1.410757, 2.115155]

# %%
core12 = []
with open("12.txt", "r") as file:
    lines = file.readlines()
for i, line in enumerate(lines):
    lines[i] = line.split(", ")[1].strip()
core12 = list(map(float, lines))
print(core12)
# Out:
# [0.001773, 0.007139, 0.024407, 0.065209, 0.142773, 0.277724, 0.493081, 0.821198, 1.301652, 1.969845]

# %%
size = list(range(100, 1001, 100))
print(size)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]

# %%
plt.plot(size, core1)
plt.plot(size, core6)
plt.plot(size, core12)
plt.legend(["1 core", "6 cores", "12 cores"]) 
plt.show()
